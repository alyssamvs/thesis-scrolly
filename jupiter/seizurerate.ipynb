# %%
import pandas as pd
import numpy as np
from datetime import datetime, timedelta


df = pd.read_csv('data/full_ids_seizuresperyear.csv')

# %%
df['Country/Territory of Seizure'].unique()
# Out:
# array(['Albania', 'Algeria', 'Andorra', 'Antigua and Barbuda', 'Armenia',
#        'Austria', 'Azerbaijan', 'Bahamas', 'Belarus', 'Belgium', 'Benin',
#        'Bolivia (Plurinational State of)', 'Bosnia and Herzegovina',
#        'Botswana', 'Brazil', 'Brunei Darussalam', 'Bulgaria',
#        'Burkina Faso', 'Cambodia', 'Cameroon', 'Canada', 'Chile', 'China',
#        'China, Hong Kong SAR', 'China, Macao SAR', 'Colombia',
#        'Costa Rica', 'Croatia', 'Cuba', 'Cyprus', 'Czech Republic',
#        'Czechia', 'Denmark', 'Dominican Republic', 'Ecuador',
#        'El Salvador', 'Estonia', 'Finland', 'France', 'Gambia', 'Germany',
#        'Ghana', 'Greece', 'Guatemala', 'Guinea', 'Guinea-Bissau',
#        'Honduras', 'Hungary', 'Iceland', 'India',
#        'Iran (Islamic Republic of)', 'Ireland', 'Italy', 'Japan',
#        'Jordan', 'Kazakhstan', 'Kenya', 'Korea, Republic of', 'Latvia',
#        'Lebanon', 'Libya', 'Libyan Arab Jamahiriya', 'Lithuania',
# ...

# %%
countries_of_interest = ["France", "Greece", "Netherlands", "Spain", "United States of America", "Portugal", "Sweden", "Peru", "Colombia", "Brazil", "Bolivia (Plurinational State of)", "Belgium"]

df_12countries = df[df['Country/Territory of Seizure'].isin(countries_of_interest)].copy()

# %%
df_12countries.to_csv('12countries-seizuresperyear.csv', index=False)
